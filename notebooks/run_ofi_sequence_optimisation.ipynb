# %%
# Mount Drive and set up repo
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

repo_dir = "/content/gh0st-in-the-l00p"

if os.path.exists(repo_dir):
  # !git -C {repo_dir} fetch
  # !git -C {repo_dir} checkout claude/sad-satoshi
  # !git -C {repo_dir} pull
else:
  # !git clone https://github.com/jasonr2048/gh0st-in-the-l00p.git {repo_dir}
  # !git -C {repo_dir} checkout claude/sad-satoshi
  # %cd {repo_dir}
  # !pip install ultralytics matplotlib -q
# Out:
# Cloning into '/content/gh0st-in-the-l00p'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 86 (delta 27), reused 73 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 44.44 KiB | 3.42 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# Branch 'claude/sad-satoshi' set up to track remote branch 'claude/sad-satoshi' from 'origin'.
# Switched to a new branch 'claude/sad-satoshi'
# /content/gh0st-in-the-l00p
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.5 MB/s eta 0:00:00

# %%
# !python spikes/optical_flow_interpolation/optimise_sequence.py \
  --prepared_dir "/content/drive/MyDrive/Gh0st in the Loop/dataset/prepared" \
  --sets rhinestones,clown,blue_face,latex_skin,horror_drip \
  --output data/sequence.json
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#   rhinestones: 7 images
#   clown: 4 images
#   blue_face: 8 images
#   latex_skin: 4 images
#   horror_drip: 4 images
#
# Total images: 27
#
# Loading YOLOv8 pose model...
# ...
#
# Extracting keypoints...
#   [1/27] taslar (1).png ... (0.389, 0.484)
#   [2/27] taslar (2).png ... (0.501, 0.481)
#   [3/27] taslar (3).png ... (0.615, 0.481)
#   [4/27] taslar (4).png ... (0.402, 0.485)
#   [5/27] taslar (5).png ... (0.382, 0.484)
#   [6/27] taslar (6).png ... (0.602, 0.495)
#   [7/27] taslar (7).png ... (0.599, 0.488)
#   [8/27] Clown.png ... (0.521, 0.490)
#   [9/27] Clown1 (1).png ... (0.483, 0.463)
#   [10/27] Clown1 (2).png ... (0.379, 0.472)
# ...

# %%
import shutil, os

drive_out = "/content/drive/MyDrive/Gh0st in the Loop/outputs/sequence.json"
os.makedirs(os.path.dirname(drive_out), exist_ok=True)
shutil.copy("data/sequence.json", drive_out)
print(f"Saved to Drive: {drive_out}")
# Out:
# Saved to Drive: /content/drive/MyDrive/Gh0st in the Loop/outputs/sequence.json
